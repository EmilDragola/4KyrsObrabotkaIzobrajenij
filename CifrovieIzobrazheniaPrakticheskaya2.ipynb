# %%
# !import numpy as np
import cv2
import os
import argparse
import matplotlib.pyplot as plt

# %%
# составляем парсер аргументов и анализируем их
ap = argparse.ArgumentParser()
ap.add_argument('-f', '-i' '--image', help = '/content/Et_7.png')
args = vars(ap.parse_args())
# загружаем изображение
image = cv2.imread('/content/Et_7.png')
# применяем медианный фильтр 3 × 3 к изображению
processed_image = cv2.medianBlur(image, 3)
# Выводим изображение
# Сохраняем изображение в папку с проектом
cv2.imwrite('processed_Et_7.png', processed_image)
# Out:
# True

# %%
plt.imshow(cv2.cvtColor(processed_image, cv2.COLOR_BGR2RGB))

# %%
# составляем парсер аргументов и анализируем их
ap = argparse.ArgumentParser()
ap.add_argument('-f', '-i' '--image', help = '/content/Image2')
args = vars(ap.parse_args())
# загружаем изображение
image2 = cv2.imread('/content/Image2.jpg')
# применяем медианный фильтр 3 × 3 к изображению
processed_image2 = cv2.medianBlur(image2, 3)
# Выводим изображение
# Сохраняем изображение в папку с проектом
cv2.imwrite('processed_Image2.jpg', processed_image2)
plt.imshow(cv2.cvtColor(processed_image2, cv2.COLOR_BGR2RGB))

# %% [markdown]
# После применения медианного фильтра на случайном изображении, мы получили его "смазанную" версию, данный фильтр уменьшил резкость и сделал изображение слегка мыльным, но вместе с тем и слегка плавным

# %%
# Составляем парсер аргументов и анализируем их
ap = argparse.ArgumentParser()
ap.add_argument('-f', '-i', '--image', help = '/content/Image2')
args = vars(ap.parse_args())
# Загружаем изображение
image2 = cv2.imread('Image2.jpg')
# Применяем фильтр средних часот 3x3 к изображению
kernel = np.ones((3,3),np.float32)/9
processed_image2 = cv2.filter2D(image2,-1,kernel)
# Выводим изображение
# Сохраняем изображение в папку с проектом
cv2.imwrite('processed_image2.2.png', processed_image2)
plt.imshow(cv2.cvtColor(processed_image2, cv2.COLOR_BGR2RGB))

# %% [markdown]
# Средний фильтр заменяет каждый пиксель в выходном изображении на среднее значение окрестности. Это приводит к сглаживанию изображения
# (уменьшению количества вариаций интенсивности между пикселем и
# следующим), удалению шума с изображения и повышению яркости
# изображения. В данном случае, если сравнить исходное изображение и полученное в результате средней фильтрации, то можно сделать вывод, что человек, который стоит возле здания - стал более заметным, а колеса у повозки стали более детальными, общая гамма стала ярче.

# %%
# составляем парсер аргументов и анализируем их
ap = argparse.ArgumentParser()
ap.add_argument('-f', '-i' '--image', help = '/content/Image3')
args = vars(ap.parse_args())
# загружаем изображение
image3 = cv2.imread('/content/Image3.jpg')
# применяем медианный фильтр 3 × 3 к изображению
processed_image3 = cv2.medianBlur(image3, 3)
# Выводим изображение
# Сохраняем изображение в папку с проектом
cv2.imwrite('processed_Image3.jpg', processed_image3)
plt.imshow(cv2.cvtColor(processed_image3, cv2.COLOR_BGR2RGB))

# %% [markdown]
# После применения медианного фильтра на случайном изображении, мы получили его "смазанную" версию, данный фильтр уменьшил резкость и сделал изображение слегка мыльным, но вместе с тем и слегка плавным

# %%
# Составляем парсер аргументов и анализируем их
ap = argparse.ArgumentParser()
ap.add_argument('-f', '-i', '--image', help = '/content/Image3')
args = vars(ap.parse_args())
# Загружаем изображение
image3 = cv2.imread('Image3.jpg')
# Применяем фильтр средних часот 3x3 к изображению
kernel = np.ones((3,3),np.float32)/9
processed_image3 = cv2.filter2D(image3,-1,kernel)
# Выводим изображение
# Сохраняем изображение в папку с проектом
cv2.imwrite('processed_image3.2.png', processed_image3)
plt.imshow(cv2.cvtColor(processed_image3, cv2.COLOR_BGR2RGB))

# %% [markdown]
# Средний фильтр заменяет каждый пиксель в выходном изображении на среднее значение окрестности. Это приводит к сглаживанию изображения
# (уменьшению количества вариаций интенсивности между пикселем и
# следующим), удалению шума с изображения и повышению яркости
# изображения. В данном случае, если сравнить исходное изображение и полученное в результате средней фильтрации, то можно сделать вывод, что окна здания слева стали слегка плавнее, нет ощущения жестких квадратных пикселей, которые образуются шумами. Все детали получили небольшую корректировку, которая сделала картину менее четкой, но более плавной, с уменьшенным общим шумом.

# %%
# составляем парсер аргументов и анализируем их
ap = argparse.ArgumentParser()
ap.add_argument('-f', '-i' '--image', help = '/content/Image4')
args = vars(ap.parse_args())
# загружаем изображение
image4 = cv2.imread('/content/Image4.jpg')
# применяем медианный фильтр 3 × 3 к изображению
processed_image4 = cv2.medianBlur(image4, 3)
# Выводим изображение
# Сохраняем изображение в папку с проектом
cv2.imwrite('processed_Image4.jpg', processed_image4)
plt.imshow(cv2.cvtColor(processed_image4, cv2.COLOR_BGR2RGB))

# %% [markdown]
# После применения медианного фильтра на случайном изображении, мы получили его "смазанную" версию, данный фильтр уменьшил резкость и сделал изображение слегка мыльным, но вместе с тем и слегка плавным

# %%
# Составляем парсер аргументов и анализируем их
ap = argparse.ArgumentParser()
ap.add_argument('-f', '-i', '--image', help = '/content/Image4')
args = vars(ap.parse_args())
# Загружаем изображение
image4 = cv2.imread('Image4.jpg')
# Применяем фильтр средних часот 3x3 к изображению
kernel = np.ones((3,3),np.float32)/9
processed_image4 = cv2.filter2D(image4,-1,kernel)
# Выводим изображение
# Сохраняем изображение в папку с проектом
cv2.imwrite('processed_image4.2.png', processed_image4)
plt.imshow(cv2.cvtColor(processed_image4, cv2.COLOR_BGR2RGB))

# %% [markdown]
# Средний фильтр заменяет каждый пиксель в выходном изображении на среднее значение окрестности. Это приводит к сглаживанию изображения
# (уменьшению количества вариаций интенсивности между пикселем и
# следующим), удалению шума с изображения и повышению яркости
# изображения. В данном случае, если сравнить исходное изображение и полученное в результате средней фильтрации, то можно сделать вывод, что толпа справа - стала ярче, лица стали распозноваться лучше, а фасад здания - стал более детализированным в тени, исчез пересвет у исходного изображения.

# %%
# составляем парсер аргументов и анализируем их
ap = argparse.ArgumentParser()
ap.add_argument('-f', '-i' '--image', help = '/content/Image5')
args = vars(ap.parse_args())
# загружаем изображение
image5 = cv2.imread('/content/Image5.jpg')
# применяем медианный фильтр 3 × 3 к изображению
processed_image5 = cv2.medianBlur(image5, 3)
# Выводим изображение
# Сохраняем изображение в папку с проектом
cv2.imwrite('processed_Image5.jpg', processed_image5)
plt.imshow(cv2.cvtColor(processed_image5, cv2.COLOR_BGR2RGB))

# %% [markdown]
# После применения медианного фильтра на случайном изображении, мы получили его "смазанную" версию, данный фильтр уменьшил резкость и сделал изображение слегка мыльным, но вместе с тем и слегка плавным

# %%
# Составляем парсер аргументов и анализируем их
ap = argparse.ArgumentParser()
ap.add_argument('-f', '-i', '--image', help = '/content/Image5')
args = vars(ap.parse_args())
# Загружаем изображение
image5 = cv2.imread('Image5.jpg')
# Применяем фильтр средних часот 3x3 к изображению
kernel = np.ones((3,3),np.float32)/9
processed_image5 = cv2.filter2D(image5,-1,kernel)
# Выводим изображение
# Сохраняем изображение в папку с проектом
cv2.imwrite('processed_image5.2.png', processed_image5)
plt.imshow(cv2.cvtColor(processed_image5, cv2.COLOR_BGR2RGB))

# %% [markdown]
# Средний фильтр заменяет каждый пиксель в выходном изображении на среднее значение окрестности. Это приводит к сглаживанию изображения
# (уменьшению количества вариаций интенсивности между пикселем и
# следующим), удалению шума с изображения и повышению яркости
# изображения. В данном случае, если сравнить исходное изображение и полученное в результате средней фильтрации, то можно сделать вывод, что все изображение сгладилось, лучше всего заметно это на переднем плане, если вглдяется в головной убор мужчины в середине экрана - видно, что он приобрел более плавный пиксельный переход, нежели убор в исходнике.

# %% [markdown]
# # Задание 2

# %%
import numpy as np
import argparse
import imutils
import matplotlib.pyplot as plt
import cv2
# Составляем парсер аргументов и анализируем их
ap = argparse.ArgumentParser()
ap.add_argument("-f", "-p", "--image", help="/content/pic/IMAGE.jpg") # Путь к исходному изображению
ap.add_argument("-g","-w", "--fragment", help="/content/pic/Et_1.png") # Путь к фрагменту изображения (эталону)
args = vars(ap.parse_args())
# Загружаем изображение и фрагмент изображения
image = cv2.imread("/content/pic/IMAGE.jpg") # Путь к исходному изображению
fragment = cv2.imread("/content/pic/Et_1.png") # Путь к фрагменту изображения (эталону)
(fragmentHeight, fragmentWidth) = fragment.shape[:2]
# Осуществляем поиск фрагмента на изображении
result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)
# Выделяем искомый фрагмент и отделяем его от изображения
topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]
# Создаем затемненный прозрачный слой, для затемнения всей части изображения
mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)
# Возвращаем искомый фрагмент в изображение
image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi
# Вывод фрагмента и изображения в отдельные окна (закрываются при нажатии любой клавиши на клавиатуре)
cv2.imwrite('IMAGEFG1.jpg', image)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
ap = argparse.ArgumentParser()
ap.add_argument("-f", "-p", "--image", help="/content/pic/IMAGE.jpg") # Путь к исходному изображению
ap.add_argument("-g","-w", "--fragment", help="/content/pic/Et_2.png") # Путь к фрагменту изображения (эталону)
args = vars(ap.parse_args())
# Загружаем изображение и фрагмент изображения
image = cv2.imread("/content/pic/IMAGE.jpg") # Путь к исходному изображению
fragment = cv2.imread("/content/pic/Et_2.png") # Путь к фрагменту изображения (эталону)
(fragmentHeight, fragmentWidth) = fragment.shape[:2]
# Осуществляем поиск фрагмента на изображении
result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)
# Выделяем искомый фрагмент и отделяем его от изображения
topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]
# Создаем затемненный прозрачный слой, для затемнения всей части изображения
mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)
# Возвращаем искомый фрагмент в изображение
image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi
# Вывод фрагмента и изображения в отдельные окна (закрываются при нажатии любой клавиши на клавиатуре)
cv2.imwrite('IMAGEFG2.jpg', image)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
ap = argparse.ArgumentParser()
ap.add_argument("-f", "-p", "--image", help="/content/pic/IMAGE.jpg") # Путь к исходному изображению
ap.add_argument("-g","-w", "--fragment", help="/content/pic/Et_3.png") # Путь к фрагменту изображения (эталону)
args = vars(ap.parse_args())
# Загружаем изображение и фрагмент изображения
image = cv2.imread("/content/pic/IMAGE.jpg") # Путь к исходному изображению
fragment = cv2.imread("/content/pic/Et_3.png") # Путь к фрагменту изображения (эталону)
(fragmentHeight, fragmentWidth) = fragment.shape[:2]
# Осуществляем поиск фрагмента на изображении
result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)
# Выделяем искомый фрагмент и отделяем его от изображения
topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]
# Создаем затемненный прозрачный слой, для затемнения всей части изображения
mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)
# Возвращаем искомый фрагмент в изображение
image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi
# Вывод фрагмента и изображения в отдельные окна (закрываются при нажатии любой клавиши на клавиатуре)
cv2.imwrite('IMAGEFG3.jpg', image)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
ap = argparse.ArgumentParser()
ap.add_argument("-f", "-p", "--image", help="/content/pic/IMAGE.jpg") # Путь к исходному изображению
ap.add_argument("-g","-w", "--fragment", help="/content/pic/Et_4.png") # Путь к фрагменту изображения (эталону)
args = vars(ap.parse_args())
# Загружаем изображение и фрагмент изображения
image = cv2.imread("/content/pic/IMAGE.jpg") # Путь к исходному изображению
fragment = cv2.imread("/content/pic/Et_4.png") # Путь к фрагменту изображения (эталону)
(fragmentHeight, fragmentWidth) = fragment.shape[:2]
# Осуществляем поиск фрагмента на изображении
result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)
# Выделяем искомый фрагмент и отделяем его от изображения
topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]
# Создаем затемненный прозрачный слой, для затемнения всей части изображения
mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)
# Возвращаем искомый фрагмент в изображение
image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi
# Вывод фрагмента и изображения в отдельные окна (закрываются при нажатии любой клавиши на клавиатуре)
cv2.imwrite('IMAGEFG4.jpg', image)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
ap = argparse.ArgumentParser()
ap.add_argument("-f", "-p", "--image", help="/content/pic/IMAGE.jpg") # Путь к исходному изображению
ap.add_argument("-g","-w", "--fragment", help="/content/pic/Et_5.png") # Путь к фрагменту изображения (эталону)
args = vars(ap.parse_args())
# Загружаем изображение и фрагмент изображения
image = cv2.imread("/content/pic/IMAGE.jpg") # Путь к исходному изображению
fragment = cv2.imread("/content/pic/Et_5.png") # Путь к фрагменту изображения (эталону)
(fragmentHeight, fragmentWidth) = fragment.shape[:2]
# Осуществляем поиск фрагмента на изображении
result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)
# Выделяем искомый фрагмент и отделяем его от изображения
topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]
# Создаем затемненный прозрачный слой, для затемнения всей части изображения
mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)
# Возвращаем искомый фрагмент в изображение
image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi
# Вывод фрагмента и изображения в отдельные окна (закрываются при нажатии любой клавиши на клавиатуре)
cv2.imwrite('IMAGEFG5.jpg', image)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
ap = argparse.ArgumentParser()
ap.add_argument("-f", "-p", "--image", help="/content/pic/IMAGE.jpg") # Путь к исходному изображению
ap.add_argument("-g","-w", "--fragment", help="/content/pic/Et_6.png") # Путь к фрагменту изображения (эталону)
args = vars(ap.parse_args())
# Загружаем изображение и фрагмент изображения
image = cv2.imread("/content/pic/IMAGE.jpg") # Путь к исходному изображению
fragment = cv2.imread("/content/pic/Et_6.png") # Путь к фрагменту изображения (эталону)
(fragmentHeight, fragmentWidth) = fragment.shape[:2]
# Осуществляем поиск фрагмента на изображении
result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)
# Выделяем искомый фрагмент и отделяем его от изображения
topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]
# Создаем затемненный прозрачный слой, для затемнения всей части изображения
mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)
# Возвращаем искомый фрагмент в изображение
image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi
# Вывод фрагмента и изображения в отдельные окна (закрываются при нажатии любой клавиши на клавиатуре)
cv2.imwrite('IMAGEFG6.jpg', image)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
ap = argparse.ArgumentParser()
ap.add_argument("-f", "-p", "--image", help="/content/pic/IMAGE.jpg") # Путь к исходному изображению
ap.add_argument("-g","-w", "--fragment", help="/content/pic/Et_7.png") # Путь к фрагменту изображения (эталону)
args = vars(ap.parse_args())
# Загружаем изображение и фрагмент изображения
image = cv2.imread("/content/pic/IMAGE.jpg") # Путь к исходному изображению
fragment = cv2.imread("/content/pic/Et_7.png") # Путь к фрагменту изображения (эталону)
(fragmentHeight, fragmentWidth) = fragment.shape[:2]
# Осуществляем поиск фрагмента на изображении
result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)
# Выделяем искомый фрагмент и отделяем его от изображения
topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]
# Создаем затемненный прозрачный слой, для затемнения всей части изображения
mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)
# Возвращаем искомый фрагмент в изображение
image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi
# Вывод фрагмента и изображения в отдельные окна (закрываются при нажатии любой клавиши на клавиатуре)
cv2.imwrite('IMAGEFG7.jpg', image)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
ap = argparse.ArgumentParser()
ap.add_argument("-f", "-p", "--image", help="/content/pic/IMAGE.jpg") # Путь к исходному изображению
ap.add_argument("-g","-w", "--fragment", help="/content/pic/Et_8.png") # Путь к фрагменту изображения (эталону)
args = vars(ap.parse_args())
# Загружаем изображение и фрагмент изображения
image = cv2.imread("/content/pic/IMAGE.jpg") # Путь к исходному изображению
fragment = cv2.imread("/content/pic/Et_8.png") # Путь к фрагменту изображения (эталону)
(fragmentHeight, fragmentWidth) = fragment.shape[:2]
# Осуществляем поиск фрагмента на изображении
result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)
# Выделяем искомый фрагмент и отделяем его от изображения
topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]
# Создаем затемненный прозрачный слой, для затемнения всей части изображения
mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)
# Возвращаем искомый фрагмент в изображение
image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi
# Вывод фрагмента и изображения в отдельные окна (закрываются при нажатии любой клавиши на клавиатуре)
cv2.imwrite('IMAGEFG8.jpg', image)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
ap = argparse.ArgumentParser()
ap.add_argument("-f", "-p", "--image", help="/content/pic/IMAGE.jpg") # Путь к исходному изображению
ap.add_argument("-g","-w", "--fragment", help="/content/pic/Et_9.png") # Путь к фрагменту изображения (эталону)
args = vars(ap.parse_args())
# Загружаем изображение и фрагмент изображения
image = cv2.imread("/content/pic/IMAGE.jpg") # Путь к исходному изображению
fragment = cv2.imread("/content/pic/Et_9.png") # Путь к фрагменту изображения (эталону)
(fragmentHeight, fragmentWidth) = fragment.shape[:2]
# Осуществляем поиск фрагмента на изображении
result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)
# Выделяем искомый фрагмент и отделяем его от изображения
topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]
# Создаем затемненный прозрачный слой, для затемнения всей части изображения
mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)
# Возвращаем искомый фрагмент в изображение
image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi
# Вывод фрагмента и изображения в отдельные окна (закрываются при нажатии любой клавиши на клавиатуре)
cv2.imwrite('IMAGEFG9.jpg', image)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
ap = argparse.ArgumentParser()
ap.add_argument("-f", "-p", "--image", help="/content/pic/IMAGE.jpg") # Путь к исходному изображению
ap.add_argument("-g","-w", "--fragment", help="/content/pic/Et_10.png") # Путь к фрагменту изображения (эталону)
args = vars(ap.parse_args())
# Загружаем изображение и фрагмент изображения
image = cv2.imread("/content/pic/IMAGE.jpg") # Путь к исходному изображению
fragment = cv2.imread("/content/pic/Et_10.png") # Путь к фрагменту изображения (эталону)
(fragmentHeight, fragmentWidth) = fragment.shape[:2]
# Осуществляем поиск фрагмента на изображении
result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)
# Выделяем искомый фрагмент и отделяем его от изображения
topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]
# Создаем затемненный прозрачный слой, для затемнения всей части изображения
mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)
# Возвращаем искомый фрагмент в изображение
image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi
# Вывод фрагмента и изображения в отдельные окна (закрываются при нажатии любой клавиши на клавиатуре)
cv2.imwrite('IMAGEFG10.jpg', image)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Задание 3

# %%
ap = argparse.ArgumentParser()
ap.add_argument("-f", "-p", "--image", help="/content/pic/IMAGE.jpg") # Путь к исходному изображению
ap.add_argument("-g","-w", "--fragment", help="/content/pic/Et_11.png") # Путь к фрагменту изображения (эталону)
args = vars(ap.parse_args())
# Загружаем изображение и фрагмент изображения
image = cv2.imread("/content/pic/IMAGE.jpg") # Путь к исходному изображению
fragment = cv2.imread("/content/pic/Et_11.png") # Путь к фрагменту изображения (эталону)
(fragmentHeight, fragmentWidth) = fragment.shape[:2]
# Осуществляем поиск фрагмента на изображении
result = cv2.matchTemplate(image, fragment, cv2.TM_CCOEFF)
(_, _, minLoc, maxLoc) = cv2.minMaxLoc(result)
# Выделяем искомый фрагмент и отделяем его от изображения
topLeft = maxLoc
botRight = (topLeft[0] + fragmentWidth, topLeft[1] + fragmentHeight)
roi = image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]]
# Создаем затемненный прозрачный слой, для затемнения всей части изображения
mask = np.zeros(image.shape, dtype="uint8")
image = cv2.addWeighted(image, 0.20, mask, 0.75, 0)
# Возвращаем искомый фрагмент в изображение
image[topLeft[1]:botRight[1], topLeft[0]:botRight[0]] = roi
# Вывод фрагмента и изображения в отдельные окна (закрываются при нажатии любой клавиши на клавиатуре)
cv2.imwrite('IMAGEFG11.jpg', image)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
